# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
llm = ChatGroq(model='llama-3.3-70b-versatile')

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.',
#  'explanation': 'The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a play on words. \n\nIn this joke, "crusty" has a double meaning. In one sense, the crust is a part of a pizza, referring to the outer layer of bread that holds the toppings. However, "crusty" can also be used to describe someone who is irritable, grumpy, or in a bad mood.\n\nThe joke relies on this wordplay to create humor. The setup "Why was the pizza in a bad mood?" primes the listener to expect a reason for the pizza\'s bad mood. The punchline "Because it was feeling a little crusty" then subverts this expectation by using the word "crusty" in a way that references both the pizza\'s physical composition and its emotional state. This unexpected twist creates the humor in the joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a play on words. \n\nIn this joke, "crusty" has a double meaning. In one sense, the crust is a part of a pizza, referring to the outer layer of bread that holds the toppings. However, "crusty" can also be used to describe someone who is irritable, grumpy, or in a bad mood.\n\nThe joke relies on this wordplay to create humor. The setup "Why was the pizza in a bad mood?" primes the listener to expect a reason for the pizza\'s bad mood. The punchline "Because it was feeling a little crusty" then subverts this expectation by using the word "crusty" in a way that references both the pizza\'s physical composition and its emotional state. This unexpected twist creates the humor in the joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a play on words. \n\nIn this joke, "crusty" has a double meaning. In one sense, the crust is a part of a pizza, referring to the outer layer of bread that holds the toppings. However, "crusty" can also be used to describe someone who is irritable, grumpy, or in a bad mood.\n\nThe joke relies on this wordplay to create humor. The setup "Why was the pizza in a bad mood?" primes the listener to expect a reason for the pizza\'s bad mood. The punchline "Because it was feeling a little crusty" then subverts this expectation by using the word "crusty" in a way that references both the pizza\'s physical composition and its emotional state. This unexpected twist creates the humor in the joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '',
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the pasta go to therapy?\n\nBecause it was feeling a little "drained" and wanted to work through some "saucy" issues.',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a play on words. \n\nIn this joke, "crusty" has a double meaning. In one sense, the crust is a part of a pizza, referring to the outer layer of bread that holds the toppings. However, "crusty" can also be used to describe someone who is irritable, grumpy, or in a bad mood.\n\nThe joke relies on this wordplay to create humor. The setup "Why was the pizza in a bad mood?" primes the listener to expect a reason for the pizza\'s bad mood. The punchline "Because it was feeling a little crusty" then subverts this expectation by using the word "crusty" in a way that references both the pizza\'s physical composition and its emotional state. This unexpected twist creates the humor in the joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why was the pizza in a bad mood? Because it was feeling a little crusty" is a play on words. \n\nIn this joke, "crusty" has a double meaning. In one sense, the crust is a part of a pizza, referring to the outer layer of bread that holds the toppings. However, "crusty" can also be used to describe someone who is irritable, grumpy, or in a bad mood.\n\nThe joke relies on this wordplay to create humor. The setup "Why was the pizza in a bad mood?" primes the listener to expect a reason for the pizza\'s bad mood. The punchline "Because it was feeling a little crusty" then subverts this expectation by using the word "crusty" in a way that references both the pizza\'s physical composition and its emotional state. This unexpected twist creates the humor in the joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '',
# ...

# %% [markdown]
# Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).");
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ❌ Kernel manually interrupted (crash simulated).

# %%
graph.get_state({"configurable": {"thread_id":'thread-1'}})
# Out:
# StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f15b8f6-959e-6873-8004-39a33aaba998'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-05-29T18:51:33.114650+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f15b8f6-9595-6ee9-8003-727423249299'}}, tasks=(PregelTask(id='2dda8308-aa8b-792c-70ca-a6dc249d593c', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f15b8f6-959e-6873-8004-39a33aaba998'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-05-29T18:51:33.114650+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f15b8f6-9595-6ee9-8003-727423249299'}}, tasks=(PregelTask(id='2dda8308-aa8b-792c-70ca-a6dc249d593c', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
# 6. Re-run to show fault-tolerance resume
final_state = graph.invoke(
    {"input": "your input here"},
    config={"configurable": {"thread_id": "thread_1"}}
)
print("\n Final State:", final_state)
# Out:
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 6. Re-run to show fault-tolerance resume
# ----> 2 final_state = graph.invoke(
#       3     {"input": "your input here"},
#       4     config={"configurable": {"thread_id": "thread_1"}}
#       5 )
#       6 print("\n Final State:", final_state)
#
# File ~/Desktop/Gen Ai/LangGraph/myenv/lib/python3.10/site-packages/langgraph/pregel/main.py:3880, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3877             chunks.append(chunk)
#    3878 else:
#    3879     # v1: collect interrupts from updates stream
# -> 3880     for chunk in self.stream(
#    3881         input,
# ...

# %% [markdown]
# Human-in-the-Loop (HITL) is a LangGraph pattern where the graph pauses and waits for human input/approval before continuing.How it works:
# graph runs → hits interrupt → pauses → human reviews/inputs → graph resumes

# %% [markdown]
# Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f15b8d6-b7cd-624e-8000-6caaee3bfb94"}})
# Out:
# StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f15b8d6-b7cd-624e-8000-6caaee3bfb94'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-05-29T18:37:17.705412+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f15b8d6-b7be-6033-bfff-b363a55a3107'}}, tasks=(PregelTask(id='f6386b6e-ad89-bdcc-f169-2f27937224c9', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f15b8d6-b7cd-624e-8000-6caaee3bfb94"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.',
#  'explanation': 'This joke is a play on words, using a common phrase "feeling a little crusty" which typically means being irritable or grumpy, often due to being tired or in a bad mood. However, in this joke, the phrase takes on a double meaning.\n\nThe joke is about a pizza, which is a type of food that has a crust. So, when it says the pizza is "feeling a little crusty", it\'s making a pun on the fact that a pizza has a crust, but also referencing the phrase that means being irritable.\n\nIn essence, the joke is using wordplay to create a humorous connection between the characteristic of a pizza (having a crust) and a common phrase used to describe someone\'s mood (feeling crusty). The result is a lighthearted and clever joke that plays on the multiple meanings of the word "crusty".'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why was the pizza in a bad mood?\n\nBecause it was feeling a little crusty.', 'explanation': 'This joke is a play on words, using a common phrase "feeling a little crusty" which typically means being irritable or grumpy, often due to being tired or in a bad mood. However, in this joke, the phrase takes on a double meaning.\n\nThe joke is about a pizza, which is a type of food that has a crust. So, when it says the pizza is "feeling a little crusty", it\'s making a pun on the fact that a pizza has a crust, but also referencing the phrase that means being irritable.\n\nIn essence, the joke is using wordplay to create a humorous connection between the characteristic of a pizza (having a crust) and a common phrase used to describe someone\'s mood (feeling crusty). The result is a lighthearted and clever joke that plays on the multiple meanings of the word "crusty".'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': ''
# ...

# %% [markdown]
# Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f15b8d6-b7cd-624e-8000-6caaee3bfb94", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f15b92d-406c-6920-8001-5a0a141032b4'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f15b92d-406c-6920-8001-5a0a141032b4'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2026-05-29T19:16:00.576288+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f15b8d6-b7cd-624e-8000-6caaee3bfb94'}}, tasks=(PregelTask(id='d21ea09f-776f-6f5f-650b-23b0ae1c0b99', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f15b92d-406c-6920-8001-5a0a141032b4"}})
# Out:
# {'topic': 'samosa',
#  'joke': 'Why did the samosa go to therapy?\n\nBecause it was feeling a little "crunchy" on the outside and "empty" on the inside.',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why did the samosa go to therapy?\n\nBecause it was feeling a little "crunchy" on the outside and "empty" on the inside.', 'explanation': 'The joke "Why did the samosa go to therapy? Because it was feeling a little \'crunchy\' on the outside and \'empty\' on the inside" is a play on words that uses the physical characteristics of a samosa to make a humorous comment on emotional well-being.\n\nA samosa is a type of fried or baked pastry typically filled with spiced potatoes, peas, and onions. It has a crunchy exterior and a softer, often empty or hollow interior. In this joke, the samosa\'s physical characteristics are used as a metaphor for emotional states.\n\nThe phrase "feeling crunchy on the outside" refers to the samosa\'s exterior, which is crispy and firm. However, in an emotional context, "crunchy" can also imply a sense of toughness or hardness, suggesting that the samosa may be putting up a facade or hiding its true feeling
# ...
