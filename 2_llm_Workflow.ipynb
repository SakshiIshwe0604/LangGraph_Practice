# %%
pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in ./myenv/lib/python3.10/site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in ./myenv/lib/python3.10/site-packages (from langchain-groq) (1.4.0)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in ./myenv/lib/python3.10/site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./myenv/lib/python3.10/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./myenv/lib/python3.10/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./myenv/lib/python3.10/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.13.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./myenv/lib/python3.10/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.13.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in ./myenv/lib/python3.10/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: sniffio in ./myenv/lib/python3.10/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./myenv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./myenv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.16.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./myenv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./myenv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in ./myenv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.0.15)
# Requirement already satisfied: packaging>=23.2.0 in ./myenv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (26.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./myenv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.8.5)
# Requirement already satisfied: idna>=2.8 in ./myenv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.16)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./myenv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: certifi in ./myenv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.5.20)
# Requirement already satisfied: h11>=0.16 in ./myenv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./myenv/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in ./myenv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.11.9)
# Requirement already satisfied: requests>=2.0.0 in ./myenv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.34.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./myenv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in ./myenv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./myenv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./myenv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./myenv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.4 in ./myenv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.46.4)
# Requirement already satisfied: urllib3<3,>=1.26 in ./myenv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./myenv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="llama-3.1-8b-instant")

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# The average distance from the Earth to the Moon is about 384,400 kilometers (238,900 miles). This distance is also known as the "lunar distance" or "lunar mean distance." However, it's worth noting that the Moon's orbit is elliptical, which means that its distance from Earth varies throughout the month.
#
# At its closest point (called "perigee"), the Moon is about 363,300 kilometers (225,300 miles) away from Earth.
#
# At its farthest point (called "apogee"), the Moon is about 405,500 kilometers (252,000 miles) away from Earth.
#
# So, the distance between the Earth and the Moon can vary by as much as 42,200 kilometers (26,200 miles) over the course of a month.

# %%
model.invoke('How far is moon from the earth?').content
# Out:
# "The average distance from the Earth to the Moon is about 384,400 kilometers (238,900 miles). This distance can vary slightly due to the elliptical shape of the Moon's orbit around the Earth, which takes about 27.3 days to complete."
